# %% [markdown]
# # Imports

# %%
import os
import sys
from pathlib import Path

# Set the working directory
os.chdir("/Users/zaca2954/academics/anabaena/")

from src.file_formatting.ImageHandler import ImageHandler

# %% [markdown]
# # format the directories

# %%
# get a list of the directories inside the /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005 directory
base_dir = "/Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005"

# get a list of the directories inside the /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005 directory
directories = [x for x in Path(base_dir).iterdir() if x.is_dir()]

# %%
# now in each of these directories, create 2 new directories: "tiff", and "nd2"

# for directory in directories:
#     # get the name of the directory
#     directory_name = directory.name
#     # create the new directories
#     tiff_dir = directory / "tiff"
#     nd2_dir = directory / "nd2"
# 
#     if not tiff_dir.exists():
#         tiff_dir.mkdir()
# 
#     if not nd2_dir.exists():
#         nd2_dir.mkdir()
# 
#     # get a list of the files in the directory
#     files = [x for x in directory.iterdir() if x.is_file()]
# 
#     # now move the files to the correct directory
#     for file in files:
#         if file.suffix == ".nd2":
#             file.rename(nd2_dir / file.name)
#         elif file.suffix == ".tiff":
#             file.rename(tiff_dir / file.name)
#         else:
#             print(f"File {file} does not have a valid extension")

# %%
# now get a list of the nd2 files in the /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005 base directory and not nested into other directories
nd2_files = [x for x in Path(base_dir).iterdir() if x.is_file() and x.suffix == ".nd2"]

# %%
input_file = str(nd2_files[0])
output_dir = str(Path(base_dir))

# %%
process = ImageHandler(input_file, output_dir)

# %%
process.setup_reader()
# Out:
# ND2 File Metadata: {'height': 2044, 'width': 2048, 'date': datetime.datetime(2024, 11, 14, 12, 23, 52), 'fields_of_view': range(0, 6), 'frames': [0], 'z_levels': [], 'z_coordinates': [2108.925, 2110.025, 2109.625, 2108.925, 2109.85, 2109.0750000000003], 'total_images_per_channel': 6, 'channels': ['Mono', 'Cy5', 'Texas Red'], 'pixel_microns': 0.1625, 'num_frames': 1, 'experiment': {'description': 'ND Acquisition', 'loops': []}, 'events': []}
# ND2 Image Shape: {'x': 2048, 'y': 2044, 'c': 3, 't': 1, 'v': 6}

# %%
process.process_and_save_frames()
# Out:
# Reading input file /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006.nd2
# ['x', 'y', 'c', 'v']
# Frames:  17%|█▋        | 1/6 [00:01<00:07,  1.45s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0000_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0000_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0000_texas_red_image.tiff
# Frames:  33%|███▎      | 2/6 [00:02<00:05,  1.29s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0001_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0001_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0001_texas_red_image.tiff
# Frames:  50%|█████     | 3/6 [00:03<00:03,  1.04s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0002_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0002_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0002_texas_red_image.tiff
# Frames:  67%|██████▋   | 4/6 [00:05<00:03,  1.52s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0003_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0003_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0003_texas_red_image.tiff
# Frames:  83%|████████▎ | 5/6 [00:06<00:01,  1.24s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0004_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0004_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0004_texas_red_image.tiff
# Frames: 100%|██████████| 6/6 [00:07<00:00,  1.19s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0005_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0005_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006_0005_texas_red_image.tiff

# %%
for file in nd2_files:
    process = ImageHandler(str(file), output_dir)
    process.setup_reader()
    process.process_and_save_frames()

    # get the name of the file
    folder_number = file.split('.')[1]

    # get the name of the directory that has the folder number
    folder_dir = str(Path(base_dir) / f"set.{folder_number}")

    # shutle all of the .tiff files in the base dir into the folder_dir
    tiff_files = [x for x in Path(base_dir).iterdir() if x.is_file() and x.suffix == ".tiff"]
    for tiff_file in tiff_files:
        tiff_file.rename(Path(folder_dir) / 'tiff' / tiff_file.name)

# %%
# Assuming `nd2_files` is a list of files
if nd2_files:  # Ensure there are files to process
    file = nd2_files[0]  # Take the first file
    
    # Initialize and process the file
    process = ImageHandler(str(file), output_dir)
    process.setup_reader()
    process.process_and_save_frames()

    # Extract the folder number from the file name
    folder_number = str(file).split(".")[1]
    
    # Construct the directory path for the folder
    folder_dir = Path(base_dir) / f"set.{folder_number}"

    # Move all .tiff files from the base directory to the appropriate folder
    tiff_files = [
        x for x in Path(base_dir).iterdir() if x.is_file() and x.suffix == ".tiff"
    ]

    print(tiff_files)

    for tiff_file in tiff_files:
        destination = folder_dir / "tiff" / tiff_file.name
        

        destination.parent.mkdir(
            parents=True, exist_ok=True
        )  # Ensure the destination folder exists
        tiff_file.rename(destination)
else:
    print("No .nd2 files found in the directory")
# Out:
# Processing file: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006.nd2
# ND2 File Metadata: {'height': 2044, 'width': 2048, 'date': datetime.datetime(2024, 11, 14, 12, 23, 52), 'fields_of_view': range(0, 6), 'frames': [0], 'z_levels': [], 'z_coordinates': [2108.925, 2110.025, 2109.625, 2108.925, 2109.85, 2109.0750000000003], 'total_images_per_channel': 6, 'channels': ['Mono', 'Cy5', 'Texas Red'], 'pixel_microns': 0.1625, 'num_frames': 1, 'experiment': {'description': 'ND Acquisition', 'loops': []}, 'events': []}
# ND2 Image Shape: {'x': 2048, 'y': 2044, 'c': 3, 't': 1, 'v': 6}
# Reading input file /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006.nd2
# ['x', 'y', 'c', 'v']
# Frames:  17%|█▋        | 1/6 [00:02<00:10,  2.14s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0000_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0000_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0000_texas_red_image.tiff
# Frames:  33%|███▎      | 2/6 [00:04<00:09,  2.29s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0001_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0001_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0001_texas_red_image.tiff
# Frames:  50%|█████     | 3/6 [00:06<00:06,  2.04s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0002_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0002_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0002_texas_red_image.tiff
# Frames:  67%|██████▋   | 4/6 [00:07<00:03,  1.89s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0003_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0003_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0003_texas_red_image.tiff
# Frames:  83%|████████▎ | 5/6 [00:08<00:01,  1.48s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0004_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0004_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0004_texas_red_image.tiff
# Frames: 100%|██████████| 6/6 [00:09<00:00,  1.61s/frame]
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0005_brightfield_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0005_cy5_image.tiff
# Saved TIFF: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006/set1.006_0005_texas_red_image.tiff
# Processed file: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006.nd2
# Folder number: 006
# Folder directory: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006
# Moving 0 TIFF files to /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set.006...
# Processed file: /Users/zaca2954/academics/anabaena/anabaena_mcdb6440/20241114_ZMB_Anabaena/20241114_002_ZMB005/set1.006.nd2 and moved related TIFF files.
